# %%
# %pip install google-genai python-dotenv
# Out:
# Collecting google-genai
#   Downloading google_genai-1.73.1-py3-none-any.whl.metadata (52 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from google-genai) (4.12.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.49.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.9.0 (from google-genai)
#   Downloading pydantic-2.13.2-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from google-genai) (9.1.2)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: certifi in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.2 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading pydantic_core-2.46.2-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\nallapur\.vscode\New folder\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.23)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-1.73.1-py3-none-any.whl (783 kB)
#    ---------------------------------------- 0.0/783.6 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/783.6 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 783.6/783.6 kB 3.3 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading google_auth-2.49.2-py3-none-any.whl (240 kB)
# Downloading pydantic-2.13.2-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.2-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.1 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.3 MB/s  0:00:00
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-46.0.7-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------- ------------------------ 1.3/3.5 MB 6.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 5.5 MB/s  0:00:00
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: websockets, typing-inspection, sniffio, python-dotenv, pydantic-core, pyasn1, distro, annotated-types, pydantic, pyasn1-modules, cryptography, google-auth, google-genai
#
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    ----------------------------------------  0/13 [websockets]
#    --------- ------------------------------  3/13 [python-dotenv]
#    ------------ ---------------------------  4/13 [pydantic-core]
#    --------------- ------------------------  5/13 [pyasn1]
#    --------------- ------------------------  5/13 [pyasn1]
#    --------------------- ------------------  7/13 [annotated-types]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    ------------------------ ---------------  8/13 [pydantic]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    --------------------------- ------------  9/13 [pyasn1-modules]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    --------------------------------- ------ 11/13 [google-auth]
#    --------------------------------- ------ 11/13 [google-auth]
#    --------------------------------- ------ 11/13 [google-auth]
#    --------------------------------- ------ 11/13 [google-auth]
#    --------------------------------- ------ 11/13 [google-auth]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ------------------------------------ --- 12/13 [google-genai]
#    ---------------------------------------- 13/13 [google-genai]
#
# Successfully installed annotated-types-0.7.0 cryptography-46.0.7 distro-1.9.0 google-auth-2.49.2 google-genai-1.73.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pydantic-2.13.2 pydantic-core-2.46.2 python-dotenv-1.2.2 sniffio-1.3.1 typing-inspection-0.4.2 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# import thr necessary libraries
from google import genai
from google.genai import types
import os 
from dotenv import load_dotenv

# load .env file from directory
load_dotenv(dotenv_path=".env")

API_KEY=os.environ.get('GEMINI_API_KEY')

client = genai.Client(api_key=API_KEY)
response = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents = 'Hi my name is ganesh, i have 2 yrs of experience in ai , generate a message about me',
)
print(response.text)
# Out:
# Here are a few options for a message about you, Ganesh, with 2 years of AI experience. Choose the one that best fits the context you need it for (e.g., LinkedIn, networking, introduction).
#
# **Option 1: Concise and Professional (Good for general introductions/LinkedIn summary)**
#
# > Ganesh is an AI professional with 2 years of hands-on experience in developing and implementing AI solutions. He is passionate about leveraging cutting-edge technologies to solve complex problems and drive innovation.
#
# **Option 2: Slightly More Detail-Oriented (Good for networking)**
#
# > Hello, I'm Ganesh! I'm an AI enthusiast with 2 years of practical experience in the field. I've been involved in [mention a specific area or type of AI you worked on, if applicable, e.g., machine learning model development, data science, natural language processing]. I'm always eager to connect with others in the AI community and explore new opportunities.
#
# **Option 3: Focus on Skills and Impact (Good for a resume summary or when highlighting expertise)**
#
# > With 2 years of dedicated experience in Artificial Intelligence, Ganesh has a proven track record of [mention a quantifiable achievement or type of impact, e.g., contributing to the development of robust AI models, enhancing data-driven decision-making]. He possesses a strong understanding of [mention 1-2 key AI skills or tools you're proficient in, e.g., Python, TensorFlow, machine learning algorithms] and is driven to create impactful AI-driven solutions.
#
# **Option 4: A Bit More Personal Touch**
#
# > Hi, I'm Ganesh. I've been immersed in the exciting world of AI for the past 2 years, honing my skills in [mention a couple of key areas]. I'm deeply motivated by the potential of AI to transform industries and am constantly seeking ways to contribute to meaningful advancements.
#
# **Remember to customize!**
#
# To make these even better, consider adding:
#
# *   **Specific AI areas you've worked in:** Machine Learning, Deep Learning, Natural Language Processing (NLP), Computer Vision, Data Science, Reinforcement Learning, etc.
# *   **Key technologies or programming languages you use:** Python, TensorFlow, PyTorch, scikit-learn, etc.
# *   **A specific type of project you've enjoyed or excelled at:** Building recommendation systems, developing predictive models, data analysis, etc.
# *   **Your career goals or what you're looking for (if applicable):** "Seeking challenging roles where I can further contribute to AI innovation."
#
# **Example of a customized message:**
#
# > Hi, I'm Ganesh. I'm an AI professional with 2 years of hands-on experience in machine learning and deep learning. I've been instrumental in developing and deploying predictive models using Python and TensorFlow, leading to [mention a positive outcome]. I'm passionate about solving real-world problems with data and am always looking to connect with fellow AI enthusiasts.
#
# Choose the option that resonates most with you and then personalize it further! Good luck, Ganesh!
